# %% [markdown]
# #import libraries and dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2
import joblib
import warnings
warnings.filterwarnings('ignore')

#here i Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

#these are rwandan electricity pricing tiers (from Oct 2025)
TARIFF_RATES = {
    '0-20 kWh': 89,
    '21-50 kWh': 310,
    '50+ kWh': 369
}

# income level definitions
INCOME_LEVELS = {
    'Low': '<100,000 RWF/month',
    'Medium': '100,000-500,000 RWF/month',
    'High': '>500,000 RWF/month'
}

# Load the dataset
data = pd.read_csv('/content/rwanda_household_energy_improved.csv')
print("Dataset shape:", data.shape)
data.head(10)
# Out:
# Dataset shape: (13505, 14)
#   Household_ID        Appliance  Power_Watts  Usage_Hours_Daily  Quantity  \
# 0      HH00001             Iron         1098               0.89         1
# 1      HH00001  Washing Machine          737               1.28         1
# 2      HH00001    Phone Charger            6               3.06         3
# 3      HH00001     Refrigerator          195              12.81         1
# 4      HH00002     Water Heater         2826               1.63         1
# 5      HH00002               TV          134               2.84         1
# 6      HH00002  Electric Kettle         1197               0.50         1
# 7      HH00003         LED Lamp            8               4.63         3
# 8      HH00003     Water Heater         2630               1.56         1
# 9      HH00003      Rice Cooker          528               0.58         1
#
#    Usage_Days_Monthly  Region Income_Level  Household_Size  Total_kWh_Monthly  \
# 0                  11  Kigali       Medium               4              10.75
# 1                   6  Kigali       Medium               4               5.66
# 2                  29  Kigali       Medium               4               1.60
# 3                  30  Kigali       Medium               4              74.94
# 4                  21  Rusizi       Medium               1              96.73
# 5                  28  Rusizi       Medium               1              10.66
# 6                  21  Rusizi       Medium               1              12.57
# 7                  28    West       Medium               7               3.11
# 8                  26    West       Medium               7             106.67
# 9                  23    West       Medium               7               7.04
#
#    Household_Total_kWh Tariff_Bracket  Estimated_Bill_RWF     Month
# 0                92.95        50+ kWh            26928.55  February
# 1                92.95        50+ kWh            26928.55  February
# 2                92.95        50+ kWh            26928.55  February
# 3                92.95        50+ kWh            26928.55  February
# 4               119.96        50+ kWh            36895.24   October
# 5               119.96        50+ kWh            36895.24   October
# 6               119.96        50+ kWh            36895.24   October
# 7               116.82        50+ kWh            35736.58     March
# 8               116.82        50+ kWh            35736.58     March
# 9               116.82        50+ kWh            35736.58     March

# %% [markdown]
# #Exploratory Data Analysis and Preprocessing

# %%
# I did check for missing values
missing_values = data.isnull().sum().reset_index()
missing_values.columns = ['Column', 'Missing_Values']
display(missing_values)
# Out:
#                  Column  Missing_Values
# 0          Household_ID               0
# 1             Appliance               0
# 2           Power_Watts               0
# 3     Usage_Hours_Daily               0
# 4              Quantity               0
# 5    Usage_Days_Monthly               0
# 6                Region               0
# 7          Income_Level               0
# 8        Household_Size               0
# 9     Total_kWh_Monthly               0
# 10  Household_Total_kWh               0
# 11       Tariff_Bracket               0
# 12   Estimated_Bill_RWF               0
# 13                Month               0

# %%
# Here I did check data types
data_types = pd.DataFrame(data.dtypes, columns=['Data_Type']).reset_index()
data_types.columns = ['Column', 'Data_Type']
display(data_types)
# Out:
#                  Column Data_Type
# 0          Household_ID    object
# 1             Appliance    object
# 2           Power_Watts     int64
# 3     Usage_Hours_Daily   float64
# 4              Quantity     int64
# 5    Usage_Days_Monthly     int64
# 6                Region    object
# 7          Income_Level    object
# 8        Household_Size     int64
# 9     Total_kWh_Monthly   float64
# 10  Household_Total_kWh   float64
# 11       Tariff_Bracket    object
# 12   Estimated_Bill_RWF   float64
# 13                Month    object

# %%
# I did get basic statistics of the dataset
dataset_stats = data.describe().reset_index()
display(dataset_stats)
# Out:
#    index   Power_Watts  Usage_Hours_Daily      Quantity  Usage_Days_Monthly  \
# 0  count  13505.000000       13505.000000  13505.000000        13505.000000
# 1   mean    522.631248           3.023766      1.482044           22.499593
# 2    std    641.245624           2.813621      1.065185            7.913728
# 3    min      5.000000           0.110000      1.000000            3.000000
# 4    25%     47.000000           1.180000      1.000000           20.000000
# 5    50%    143.000000           2.070000      1.000000           25.000000
# 6    75%    860.000000           3.890000      1.000000           28.000000
# 7    max   2997.000000          17.840000      8.000000           30.000000
#
#    Household_Size  Total_kWh_Monthly  Household_Total_kWh  Estimated_Bill_RWF
# 0    13505.000000       13505.000000         13505.000000        13505.000000
# 1        3.965939          19.199189            78.067944        22000.636392
# 2        1.992178          25.549435            46.445827        16452.926365
# 3        1.000000           0.070000             0.730000           64.970000
# 4        2.000000           3.690000            37.010000         7053.100000
# 5        4.000000           9.210000            74.860000        20253.340000
# 6        6.000000          22.180000           119.800000        36836.200000
# 7        7.000000         189.660000           200.380000        66570.220000

# %%
# Here I did check for duplicates
duplicates = pd.DataFrame({'Number_of_Duplicates': [data.duplicated().sum()]})
display(duplicates)
# Out:
#    Number_of_Duplicates
# 0                     0

# %% [markdown]
# #Data Visualization

# %%
# Set professional style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 8)
plt.rcParams['font.size'] = 12
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12

# Numeric and categorical columns
numeric_cols = data.select_dtypes(include=[np.number]).columns
categorical_cols = data.select_dtypes(include=['object', 'category']).columns

# Distribution of Monthly Energy Consumption
plt.figure(figsize=(12, 6))
sns.histplot(data['Total_kWh_Monthly'], bins=30, kde=True, color='skyblue', edgecolor='black')
plt.title('Distribution of Monthly Energy Consumption (kWh)', fontsize=16)
plt.xlabel('kWh Monthly')
plt.ylabel('Frequency')
plt.show()

# Average Energy Consumption by Income Level
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Income_Level', y='Total_kWh_Monthly', data=data, palette='Reds', ci=None)
plt.title('Average Energy Consumption by Income Level', fontsize=16)
plt.xlabel('Income Level')
plt.ylabel('Average kWh Monthly')
ax.set_ylim([0, 50]) # Set y-axis limit
plt.show()

# Top 10 Appliances by Average Power Consumption
top_appliances = data.groupby('Appliance')['Power_Watts'].mean().sort_values(ascending=False)[:10]
plt.figure(figsize=(10, 6))
sns.barplot(x=top_appliances.values, y=top_appliances.index, palette='Oranges_r')
plt.title('Top 10 Appliances by Power Consumption (Watts)', fontsize=16)
plt.xlabel('Average Power (Watts)')
plt.ylabel('Appliance')
plt.show()

# Household Size vs Monthly Energy Consumption
plt.figure(figsize=(10, 6))
ax = sns.scatterplot(x='Household_Size', y='Total_kWh_Monthly', data=data, hue='Income_Level', palette='viridis', alpha=0.7, s=100)
plt.title('Household Size vs Energy Consumption', fontsize=16)
plt.xlabel('Household Size')
plt.ylabel('kWh Monthly')
plt.legend(title='Income Level')
ax.set_ylim([0, 250]) # Set y-axis limit
plt.show()

# Correlation Heatmap for Numeric Columns
plt.figure(figsize=(10, 8))
correlation_matrix = data[numeric_cols].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Numeric Variables', fontsize=16)
plt.show()

# Boxplot of Consumption by Region
plt.figure(figsize=(10, 6))
ax = sns.boxplot(x='Region', y='Total_kWh_Monthly', data=data, palette='Pastel1')
plt.title('Energy Consumption Distribution by Region', fontsize=10)
plt.xlabel('Region')
plt.ylabel('kWh Monthly')
ax.set_ylim([0, 250]) # Set y-axis limit
plt.show()

# %% [markdown]
# #Data Preprocessing and Feature Engineering

# %%
# I did create a copy of the data for preprocessing
df_processed = data.copy()

# Here I did define a function to convert power to consistent units (Watts)
def ensure_watts(power_value, appliance_name=""):
    """Ensure power is in Watts"""
    # Based on typical appliance power ranges, detect if value might be in kW
    if power_value < 1 and appliance_name in ['AC', 'Water Heater', 'Refrigerator', 'Electric Kettle', 'Iron']:
        return power_value * 1000  # Convert kW to W
    return power_value

# I did apply power conversion
df_processed['Power_Watts'] = df_processed.apply(
    lambda row: ensure_watts(row['Power_Watts'], row['Appliance']), axis=1
)

# Here I did encode categorical variables
label_encoders = {}
categorical_cols = ['Region', 'Income_Level', 'Appliance', 'Tariff_Bracket','Month']

for col in categorical_cols:
    le = LabelEncoder()
    df_processed[col] = le.fit_transform(df_processed[col])
    label_encoders[col] = le

# I did create new features for energy calculations
df_processed['Daily_Energy_kWh'] = (df_processed['Power_Watts'] * df_processed['Usage_Hours_Daily'] * df_processed['Quantity']) / 1000
df_processed['Monthly_Usage_Factor'] = df_processed['Usage_Days_Monthly'] / 30
df_processed['Appliance_Load'] = df_processed['Power_Watts'] * df_processed['Quantity']
df_processed['Energy_Intensity'] = df_processed['Total_kWh_Monthly'] / df_processed['Household_Size']

# Here I did define features and multiple targets
X = df_processed[['Appliance', 'Power_Watts', 'Usage_Hours_Daily', 'Quantity',
                  'Region', 'Income_Level',  'Usage_Days_Monthly',
                  'Household_Size', 'Daily_Energy_kWh', 'Monthly_Usage_Factor',
                  'Appliance_Load', 'Energy_Intensity']]

# I did define multiple targets
y_kwh = df_processed['Total_kWh_Monthly']
y_tariff = df_processed['Tariff_Bracket']
y_bill = df_processed['Estimated_Bill_RWF']

# I did display shapes of features and targets
display(pd.DataFrame({
    'Features_Shape': [X.shape],
    'y_kWh_Shape': [y_kwh.shape],
    'y_Tariff_Shape': [y_tariff.shape],
    'y_Bill_Shape': [y_bill.shape]
}))

# Here I did split the data into training and test sets
X_train, X_test, y_kwh_train, y_kwh_test, y_tariff_train, y_tariff_test, y_bill_train, y_bill_test = train_test_split(
    X, y_kwh, y_tariff, y_bill, test_size=0.2, random_state=42
)

# I did scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# I did display shapes of training and test sets
display(pd.DataFrame({
    'Set': ['Training', 'Test'],
    'Features_Shape': [X_train_scaled.shape, X_test_scaled.shape]
}))
# Out:
#   Features_Shape y_kWh_Shape y_Tariff_Shape y_Bill_Shape
# 0    (11000, 12)    (11000,)       (11000,)     (11000,)
#         Set Features_Shape
# 0  Training     (8800, 12)
# 1      Test     (2200, 12)

# %% [markdown]
# #Build and Train the Neural Network Model

# %%
# I did define a function to build a multi-output neural network model
def create_multi_output_model(input_shape):
    """Create a neural network with multiple outputs"""

    # Here I did define the input layer
    inputs = keras.Input(shape=(input_shape,))

    # I did create shared hidden layers
    x = layers.Dense(256, activation='relu', kernel_regularizer=l2(0.001))(inputs)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(64, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = layers.Dropout(0.2)(x)

    # I did define separate output layers

    # Output 1: kWh prediction (regression)
    kwh_output = layers.Dense(32, activation='relu')(x)
    kwh_output = layers.Dense(1, name='kwh_output')(kwh_output)

    # Output 2: Tariff bracket prediction (classification)
    tariff_output = layers.Dense(32, activation='relu')(x)
    tariff_output = layers.Dense(3, activation='softmax', name='tariff_output')(tariff_output)

    # Output 3: Bill amount prediction (regression)
    bill_output = layers.Dense(32, activation='relu')(x)
    bill_output = layers.Dense(1, name='bill_output')(bill_output)

    # Here I did create the model object
    model = keras.Model(inputs=inputs, outputs=[kwh_output, tariff_output, bill_output])

    return model

# I did create the model
model = create_multi_output_model(X_train_scaled.shape[1])

# Here I did compile the model with different loss functions and metrics for each output
model.compile(
    optimizer='adam',
    loss={
        'kwh_output': 'mse',
        'tariff_output': 'sparse_categorical_crossentropy',
        'bill_output': 'mse'
    },
    loss_weights={
        'kwh_output': 0.4,
        'tariff_output': 0.3,
        'bill_output': 0.3
    },
    metrics={
        'kwh_output': ['mae'],
        'tariff_output': ['accuracy'],
        'bill_output': ['mae']
    }
)

# I did display the model architecture
model.summary()

# Here I did define early stopping callback
early_stopping = keras.callbacks.EarlyStopping(
    patience=25,
    min_delta=0.001,
    restore_best_weights=True,
    verbose=1
)

# Here I did define learning rate reduction callback
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    factor=0.5,
    patience=10,
    min_lr=0.0001,
    verbose=1
)

# I did train the model with multiple outputs and validation data
history = model.fit(
    X_train_scaled,
    {
        'kwh_output': y_kwh_train,
        'tariff_output': y_tariff_train,
        'bill_output': y_bill_train
    },
    validation_data=(
        X_test_scaled,
        {
            'kwh_output': y_kwh_test,
            'tariff_output': y_tariff_test,
            'bill_output': y_bill_test
        }
    ),
    epochs=200,
    batch_size=64,
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 12)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 256)       │      3,328 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 128)       │     32,896 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 64)        │      8,256 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 32)        │      2,080 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 32)        │      2,080 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 32)        │      2,080 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ kwh_output (Dense)  │ (None, 1)         │         33 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tariff_output       │ (None, 3)         │         99 │ dense_10[0][0]    │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bill_output (Dense) │ (None, 1)         │         33 │ dense_11[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 50,885 (198.77 KB)
#  Trainable params: 50,885 (198.77 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - bill_output_loss: 11206051840.0000 - bill_output_mae: 52928.0977 - kwh_output_loss: 72983.3125 - kwh_output_mae: 145.8527 - loss: 3361974528.0000 - tariff_output_accuracy: 0.4600 - tariff_output_loss: 2.5948 - val_bill_output_loss: 3100625408.0000 - val_bill_output_mae: 28713.9531 - val_kwh_output_loss: 16117.8018 - val_kwh_output_mae: 66.0748 - val_loss: 940299712.0000 - val_tariff_output_accuracy: 0.4200 - val_tariff_output_loss: 23.8707 - learning_rate: 0.0010
# Epoch 2/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step
200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 163252448.0000 - bill_output_mae: 5989.1836 - kwh_output_loss: 1128.8389 - kwh_output_mae: 16.3200 - loss: 48976184.0000 - tariff_output_accuracy: 0.8951 - tariff_output_loss: 0.3552 - val_bill_output_loss: 20924206.0000 - val_bill_output_mae: 2436.8223 - val_kwh_output_loss: 1444.1567 - val_kwh_output_mae: 20.7204 - val_loss: 6270339.5000 - val_tariff_output_accuracy: 0.9509 - val_tariff_output_loss: 0.1219 - learning_rate: 5.0000e-04
# Epoch 81/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 145613424.0000 - bill_output_mae: 5786.8833 - kwh_output_loss: 1060.4811 - kwh_output_mae: 16.1011 - loss: 43682168.0000 - tariff_output_accuracy: 0.8947 - tariff_output_loss: 0.5588 - val_bill_output_loss: 20483592.0000 - val_bill_output_mae: 2382.0557 - val_kwh_output_loss: 795.1696 - val_kwh_output_mae: 15.4237 - val_loss: 6139880.0000 - val_tariff_output_accuracy: 0.9114 - val_tariff_output_loss: 0.1841 - learning_rate: 5.0000e-04
# Epoch 82/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - bill_output_loss: 173568928.0000 - bill_output_mae: 6069.3555 - kwh_output_loss: 1238.0103 - kwh_output_mae: 16.6306 - loss: 52072552.0000 - tariff_output_accuracy: 0.9091 - tariff_output_loss: 0.3394 - val_bill_output_loss: 20536192.0000 - val_bill_output_mae: 2447.9773 - val_kwh_output_loss: 722.2601 - val_kwh_output_mae: 15.1213 - val_loss: 6150785.0000 - val_tariff_output_accuracy: 0.9327 - val_tariff_output_loss: 0.1511 - learning_rate: 5.0000e-04
# Epoch 83/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - bill_output_loss: 149709408.0000 - bill_output_mae: 5940.5894 - kwh_output_loss: 1050.9808 - kwh_output_mae: 16.3018 - loss: 44914984.0000 - tariff_output_accuracy: 0.9132 - tariff_output_loss: 0.2643 - val_bill_output_loss: 17364454.0000 - val_bill_output_mae: 2217.7063 - val_kwh_output_loss: 254.8851 - val_kwh_output_mae: 8.8515 - val_loss: 5218192.5000 - val_tariff_output_accuracy: 0.9350 - val_tariff_output_loss: 0.1574 - learning_rate: 5.0000e-04
# Epoch 84/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - bill_output_loss: 167650800.0000 - bill_output_mae: 5983.4199 - kwh_output_loss: 1186.5890 - kwh_output_mae: 16.3543 - loss: 50297852.0000 - tariff_output_accuracy: 0.9116 - tariff_output_loss: 0.2578 - val_bill_output_loss: 17560598.0000 - val_bill_output_mae: 2278.7463 - val_kwh_output_loss: 455.8433 - val_kwh_output_mae: 11.7527 - val_loss: 5277760.0000 - val_tariff_output_accuracy: 0.9500 - val_tariff_output_loss: 0.1580 - learning_rate: 5.0000e-04
# Epoch 85/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - bill_output_loss: 148850608.0000 - bill_output_mae: 5752.2383 - kwh_output_loss: 1019.1326 - kwh_output_mae: 15.6687 - loss: 44655316.0000 - tariff_output_accuracy: 0.9105 - tariff_output_loss: 0.2753 - val_bill_output_loss: 17925962.0000 - val_bill_output_mae: 2312.1775 - val_kwh_output_loss: 695.7542 - val_kwh_output_mae: 14.6241 - val_loss: 5379268.5000 - val_tariff_output_accuracy: 0.9245 - val_tariff_output_loss: 0.2126 - learning_rate: 5.0000e-04
# Epoch 86/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 153490144.0000 - bill_output_mae: 5672.8154 - kwh_output_loss: 1076.2463 - kwh_output_mae: 15.5491 - loss: 46047160.0000 - tariff_output_accuracy: 0.9148 - tariff_output_loss: 0.2593 - val_bill_output_loss: 20795036.0000 - val_bill_output_mae: 2450.7383 - val_kwh_output_loss: 538.8198 - val_kwh_output_mae: 12.9429 - val_loss: 6233901.5000 - val_tariff_output_accuracy: 0.9527 - val_tariff_output_loss: 0.1319 - learning_rate: 5.0000e-04
# Epoch 87/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 150456768.0000 - bill_output_mae: 5840.6543 - kwh_output_loss: 1075.3757 - kwh_output_mae: 16.1764 - loss: 45137348.0000 - tariff_output_accuracy: 0.8960 - tariff_output_loss: 0.3772 - val_bill_output_loss: 16290341.0000 - val_bill_output_mae: 2117.0911 - val_kwh_output_loss: 202.2109 - val_kwh_output_mae: 8.3143 - val_loss: 4895607.0000 - val_tariff_output_accuracy: 0.9459 - val_tariff_output_loss: 0.1974 - learning_rate: 5.0000e-04
# Epoch 88/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 141284816.0000 - bill_output_mae: 5712.2573 - kwh_output_loss: 1068.4839 - kwh_output_mae: 15.9935 - loss: 42386672.0000 - tariff_output_accuracy: 0.8980 - tariff_output_loss: 0.3704 - val_bill_output_loss: 15713953.0000 - val_bill_output_mae: 2051.5728 - val_kwh_output_loss: 290.2039 - val_kwh_output_mae: 9.4738 - val_loss: 4720133.0000 - val_tariff_output_accuracy: 0.9395 - val_tariff_output_loss: 0.1961 - learning_rate: 5.0000e-04
# Epoch 89/200
# ...
# Epoch 109/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 143019360.0000 - bill_output_mae: 5612.4829 - kwh_output_loss: 963.4700 - kwh_output_mae: 15.0888 - loss: 42907440.0000 - tariff_output_accuracy: 0.9162 - tariff_output_loss: 0.2292 - val_bill_output_loss: 14688795.0000 - val_bill_output_mae: 1969.3173 - val_kwh_output_loss: 670.3541 - val_kwh_output_mae: 13.9742 - val_loss: 4421599.5000 - val_tariff_output_accuracy: 0.9527 - val_tariff_output_loss: 0.1098 - learning_rate: 2.5000e-04
# Epoch 110/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 132499112.0000 - bill_output_mae: 5643.8853 - kwh_output_loss: 902.8094 - kwh_output_mae: 15.4414 - loss: 39750324.0000 - tariff_output_accuracy: 0.9239 - tariff_output_loss: 0.2185 - val_bill_output_loss: 15432739.0000 - val_bill_output_mae: 2033.4755 - val_kwh_output_loss: 456.5596 - val_kwh_output_mae: 11.8080 - val_loss: 4636407.5000 - val_tariff_output_accuracy: 0.9355 - val_tariff_output_loss: 0.1447 - learning_rate: 2.5000e-04
# Epoch 111/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - bill_output_loss: 169602432.0000 - bill_output_mae: 5931.1133 - kwh_output_loss: 1117.7510 - kwh_output_mae: 16.0658 - loss: 50880264.0000 - tariff_output_accuracy: 0.9119 - tariff_output_loss: 0.2563 - val_bill_output_loss: 15967868.0000 - val_bill_output_mae: 2117.4412 - val_kwh_output_loss: 629.5638 - val_kwh_output_mae: 14.0349 - val_loss: 4790492.5000 - val_tariff_output_accuracy: 0.9564 - val_tariff_output_loss: 0.1066 - learning_rate: 2.5000e-04
# Epoch 112/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - bill_output_loss: 150016032.0000 - bill_output_mae: 5692.2622 - kwh_output_loss: 1011.1354 - kwh_output_mae: 15.5803 - loss: 45007096.0000 - tariff_output_accuracy: 0.9117 - tariff_output_loss: 0.2605 - val_bill_output_loss: 14684738.0000 - val_bill_output_mae: 1978.6472 - val_kwh_output_loss: 205.6670 - val_kwh_output_mae: 8.0322 - val_loss: 4416961.5000 - val_tariff_output_accuracy: 0.9359 - val_tariff_output_loss: 0.1336 - learning_rate: 2.5000e-04
# Epoch 113/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 165339648.0000 - bill_output_mae: 5781.2681 - kwh_output_loss: 1205.8837 - kwh_output_mae: 15.9456 - loss: 49602760.0000 - tariff_output_accuracy: 0.9171 - tariff_output_loss: 0.2316 - val_bill_output_loss: 18936262.0000 - val_bill_output_mae: 2312.5894 - val_kwh_output_loss: 1043.1915 - val_kwh_output_mae: 17.4358 - val_loss: 5672346.0000 - val_tariff_output_accuracy: 0.9436 - val_tariff_output_loss: 0.1241 - learning_rate: 2.5000e-04
# Epoch 114/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 146517360.0000 - bill_output_mae: 5752.7905 - kwh_output_loss: 953.6234 - kwh_output_mae: 15.5154 - loss: 43957200.0000 - tariff_output_accuracy: 0.9136 - tariff_output_loss: 0.2697 - val_bill_output_loss: 16215620.0000 - val_bill_output_mae: 2115.6528 - val_kwh_output_loss: 635.7274 - val_kwh_output_mae: 13.4106 - val_loss: 4859283.0000 - val_tariff_output_accuracy: 0.9127 - val_tariff_output_loss: 0.1704 - learning_rate: 2.5000e-04
# Epoch 115/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 144827648.0000 - bill_output_mae: 5706.3325 - kwh_output_loss: 996.2419 - kwh_output_mae: 15.5996 - loss: 43448732.0000 - tariff_output_accuracy: 0.9134 - tariff_output_loss: 0.2477 - val_bill_output_loss: 15376852.0000 - val_bill_output_mae: 2077.4360 - val_kwh_output_loss: 497.6713 - val_kwh_output_mae: 11.9427 - val_loss: 4616291.0000 - val_tariff_output_accuracy: 0.9091 - val_tariff_output_loss: 0.3080 - learning_rate: 2.5000e-04
# Epoch 116/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 148393456.0000 - bill_output_mae: 5765.1084 - kwh_output_loss: 988.3759 - kwh_output_mae: 15.6161 - loss: 44519952.0000 - tariff_output_accuracy: 0.9103 - tariff_output_loss: 0.2719 - val_bill_output_loss: 14980297.0000 - val_bill_output_mae: 2003.6195 - val_kwh_output_loss: 364.1768 - val_kwh_output_mae: 10.6015 - val_loss: 4509579.5000 - val_tariff_output_accuracy: 0.9368 - val_tariff_output_loss: 0.1308 - learning_rate: 2.5000e-04
# Epoch 117/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 152186512.0000 - bill_output_mae: 5781.3096 - kwh_output_loss: 1001.1422 - kwh_output_mae: 15.7791 - loss: 45657352.0000 - tariff_output_accuracy: 0.9097 - tariff_output_loss: 0.3739 - val_bill_output_loss: 16892712.0000 - val_bill_output_mae: 2210.6592 - val_kwh_output_loss: 699.9956 - val_kwh_output_mae: 14.4022 - val_loss: 5063344.5000 - val_tariff_output_accuracy: 0.9291 - val_tariff_output_loss: 0.1458 - learning_rate: 2.5000e-04
# Epoch 118/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss:
200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 144947216.0000 - bill_output_mae: 5615.2217 - kwh_output_loss: 964.2476 - kwh_output_mae: 14.9894 - loss: 43485596.0000 - tariff_output_accuracy: 0.9337 - tariff_output_loss: 0.2017 - val_bill_output_loss: 16002717.0000 - val_bill_output_mae: 2156.8123 - val_kwh_output_loss: 684.8350 - val_kwh_output_mae: 14.1769 - val_loss: 4798018.5000 - val_tariff_output_accuracy: 0.9332 - val_tariff_output_loss: 0.1334 - learning_rate: 1.2500e-04
# Epoch 125/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 141350352.0000 - bill_output_mae: 5594.3535 - kwh_output_loss: 973.0187 - kwh_output_mae: 15.1347 - loss: 42406324.0000 - tariff_output_accuracy: 0.9208 - tariff_output_loss: 0.2224 - val_bill_output_loss: 17716128.0000 - val_bill_output_mae: 2251.1274 - val_kwh_output_loss: 739.8716 - val_kwh_output_mae: 14.8965 - val_loss: 5307458.5000 - val_tariff_output_accuracy: 0.9477 - val_tariff_output_loss: 0.1085 - learning_rate: 1.2500e-04
# Epoch 126/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 152037664.0000 - bill_output_mae: 5813.9272 - kwh_output_loss: 1006.9742 - kwh_output_mae: 15.4316 - loss: 45612228.0000 - tariff_output_accuracy: 0.9176 - tariff_output_loss: 0.2325 - val_bill_output_loss: 15942060.0000 - val_bill_output_mae: 2124.1787 - val_kwh_output_loss: 644.7028 - val_kwh_output_mae: 13.7754 - val_loss: 4780723.0000 - val_tariff_output_accuracy: 0.9323 - val_tariff_output_loss: 0.1383 - learning_rate: 1.2500e-04
# Epoch 127/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 147368592.0000 - bill_output_mae: 5622.6812 - kwh_output_loss: 992.4240 - kwh_output_mae: 15.2003 - loss: 44213116.0000 - tariff_output_accuracy: 0.9183 - tariff_output_loss: 0.2097 - val_bill_output_loss: 19643026.0000 - val_bill_output_mae: 2357.7480 - val_kwh_output_loss: 710.2427 - val_kwh_output_mae: 14.3522 - val_loss: 5887880.0000 - val_tariff_output_accuracy: 0.9259 - val_tariff_output_loss: 0.1528 - learning_rate: 1.2500e-04
# Epoch 128/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - bill_output_loss: 150236944.0000 - bill_output_mae: 5820.6387 - kwh_output_loss: 1000.3315 - kwh_output_mae: 15.7193 - loss: 45072328.0000 - tariff_output_accuracy: 0.9193 - tariff_output_loss: 0.2206 - val_bill_output_loss: 15412312.0000 - val_bill_output_mae: 2103.2134 - val_kwh_output_loss: 506.4590 - val_kwh_output_mae: 12.2502 - val_loss: 4630087.0000 - val_tariff_output_accuracy: 0.9236 - val_tariff_output_loss: 0.1816 - learning_rate: 1.2500e-04
# Epoch 129/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - bill_output_loss: 155744128.0000 - bill_output_mae: 5777.9331 - kwh_output_loss: 1001.9506 - kwh_output_mae: 15.1863 - loss: 46725364.0000 - tariff_output_accuracy: 0.9252 - tariff_output_loss: 0.2113 - val_bill_output_loss: 19346102.0000 - val_bill_output_mae: 2320.6436 - val_kwh_output_loss: 742.2986 - val_kwh_output_mae: 14.4782 - val_loss: 5801000.5000 - val_tariff_output_accuracy: 0.9368 - val_tariff_output_loss: 0.1828 - learning_rate: 1.2500e-04
# Epoch 130/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - bill_output_loss: 144163200.0000 - bill_output_mae: 5537.7227 - kwh_output_loss: 967.7452 - kwh_output_mae: 14.9690 - loss: 43250532.0000 - tariff_output_accuracy: 0.9319 - tariff_output_loss: 0.1930 - val_bill_output_loss: 15296284.0000 - val_bill_output_mae: 2079.9436 - val_kwh_output_loss: 626.6425 - val_kwh_output_mae: 13.5227 - val_loss: 4595105.0000 - val_tariff_output_accuracy: 0.9377 - val_tariff_output_loss: 0.1229 - learning_rate: 1.2500e-04
# Epoch 131/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 147086352.0000 - bill_output_mae: 5713.0444 - kwh_output_loss: 999.8192 - kwh_output_mae: 15.4798 - loss: 44124704.0000 - tariff_output_accuracy: 0.9216 - tariff_output_loss: 0.2210 - val_bill_output_loss: 15578434.0000 - val_bill_output_mae: 2111.2046 - val_kwh_output_loss: 580.7510 - val_kwh_output_mae: 13.0059 - val_loss: 4677792.5000 - val_tariff_output_accuracy: 0.9382 - val_tariff_output_loss: 0.1230 - learning_rate: 1.2500e-04
# Epoch 132/200
# 136/138 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - bill_output_loss: 143746256.0000 - bill_output_mae: 5709.1143 - kwh_output_loss: 943.5583 - kwh_output_mae: 15.2115 - loss: 43124260.0000 - tariff_output_accuracy: 0.9229 - tariff_output_loss: 0.2171
# Epoch 132: ReduceLROnPlateau reducing learning rate to 0.0001.
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 144077296.0000 - bill_output_mae: 5713.7334 - kwh_output_loss: 946.0182 - kwh_output_mae: 15.2245 - loss: 43223348.0000 - tariff_output_accuracy: 0.9229 - tariff_output_loss: 0.2171 - val_bill_output_loss: 16001315.0000 - val_bill_output_mae: 2133.9526 - val_kwh_output_loss: 356.1434 - val_kwh_output_mae: 10.2843 - val_loss: 4805896.0000 - val_tariff_output_accuracy: 0.9477 - val_tariff_output_loss: 0.1139 - learning_rate: 1.2500e-04
# Epoch 133/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 139177360.0000 - bill_output_mae: 5616.6084 - kwh_output_loss: 964.5357 - kwh_output_mae: 15.3944 - loss: 41754820.0000 - tariff_output_accuracy: 0.9287 - tariff_output_loss: 0.1909 - val_bill_output_loss: 18304772.0000 - val_bill_output_mae: 2270.7405 - val_kwh_output_loss: 746.9414 - val_kwh_output_mae: 14.7242 - val_loss: 5490269.0000 - val_tariff_output_accuracy: 0.9641 - val_tariff_output_loss: 0.0960 - learning_rate: 1.0000e-04
# Epoch 134/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 155320096.0000 - bill_output_mae: 5729.7046 - kwh_output_loss: 1017.1451 - kwh_output_mae: 15.4587 - loss: 46598480.0000 - tariff_output_accuracy: 0.9218 - tariff_output_loss: 0.2192 - val_bill_output_loss: 16393256.0000 - val_bill_output_mae: 2171.9844 - val_kwh_output_loss: 505.5290 - val_kwh_output_mae: 12.1833 - val_loss: 4920430.5000 - val_tariff_output_accuracy: 0.9477 - val_tariff_output_loss: 0.1139 - learning_rate: 1.0000e-04
# Epoch 135/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 135877184.0000 - bill_output_mae: 5653.2979 - kwh_output_loss: 935.6362 - kwh_output_mae: 15.2622 - loss: 40764612.0000 - tariff_output_accuracy: 0.9198 - tariff_output_loss: 0.2074 - val_bill_output_loss: 17615582.0000 - val_bill_output_mae: 2218.0090 - val_kwh_output_loss: 603.2792 - val_kwh_output_mae: 13.1361 - val_loss: 5289764.5000 - val_tariff_output_accuracy: 0.9364 - val_tariff_output_loss: 0.1341 - learning_rate: 1.0000e-04
# Epoch 136/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 162192672.0000 - bill_output_mae: 5883.1870 - kwh_output_loss: 1062.9358 - kwh_output_mae: 15.7231 - loss: 48657712.0000 - tariff_output_accuracy: 0.9224 - tariff_output_loss: 0.2195 - val_bill_output_loss: 17196848.0000 - val_bill_output_mae: 2193.0483 - val_kwh_output_loss: 601.2828 - val_kwh_output_mae: 13.0704 - val_loss: 5162837.5000 - val_tariff_output_accuracy: 0.9509 - val_tariff_output_loss: 0.1108 - learning_rate: 1.0000e-04
# Epoch 137/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - bill_output_loss: 153634656.0000 - bill_output_mae: 5735.0659 - kwh_output_loss: 988.9279 - kwh_output_mae: 15.3858 - loss: 46090444.0000 - tariff_output_accuracy: 0.9296 - tariff_output_loss: 0.1864 - val_bill_output_loss: 16290796.0000 - val_bill_output_mae: 2129.7441 - val_kwh_output_loss: 507.1511 - val_kwh_output_mae: 11.9798 - val_loss: 4896407.0000 - val_tariff_output_accuracy: 0.9455 - val_tariff_output_loss: 0.1214 - learning_rate: 1.0000e-04
# Epoch 137: early stopping
# Restoring model weights from the end of the best epoch: 112.

# %% [markdown]
# #Model Evaluation

# %%
# Plot training history
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# kWh loss
axes[0, 0].plot(history.history['kwh_output_loss'], label='Training Loss')
axes[0, 0].plot(history.history['val_kwh_output_loss'], label='Validation Loss')
axes[0, 0].set_title('kWh Prediction Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()

# kWh MAE
axes[0, 1].plot(history.history['kwh_output_mae'], label='Training MAE')
axes[0, 1].plot(history.history['val_kwh_output_mae'], label='Validation MAE')
axes[0, 1].set_title('kWh Prediction MAE')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('MAE')
axes[0, 1].legend()

# Tariff accuracy
axes[0, 2].plot(history.history['tariff_output_accuracy'], label='Training Accuracy')
axes[0, 2].plot(history.history['val_tariff_output_accuracy'], label='Validation Accuracy')
axes[0, 2].set_title('Tariff Prediction Accuracy')
axes[0, 2].set_xlabel('Epoch')
axes[0, 2].set_ylabel('Accuracy')
axes[0, 2].legend()

# Bill loss
axes[1, 0].plot(history.history['bill_output_loss'], label='Training Loss')
axes[1, 0].plot(history.history['val_bill_output_loss'], label='Validation Loss')
axes[1, 0].set_title('Bill Prediction Loss')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Loss')
axes[1, 0].legend()

# Bill MAE
axes[1, 1].plot(history.history['bill_output_mae'], label='Training MAE')
axes[1, 1].plot(history.history['val_bill_output_mae'], label='Validation MAE')
axes[1, 1].set_title('Bill Prediction MAE')
axes[1, 1].set_ylabel('MAE')
axes[1, 1].legend()

# Total loss
axes[1, 2].plot(history.history['loss'], label='Training Loss')
axes[1, 2].plot(history.history['val_loss'], label='Validation Loss')
axes[1, 2].set_title('Total Model Loss')
axes[1, 2].set_xlabel('Epoch')
axes[1, 2].set_ylabel('Loss')
axes[1, 2].legend()

plt.tight_layout()
plt.show()

# Make predictions
y_pred_kwh, y_pred_tariff_proba, y_pred_bill = model.predict(X_test_scaled)

# Convert tariff probabilities to class predictions
y_pred_tariff = np.argmax(y_pred_tariff_proba, axis=1)

# Flatten regression outputs
y_pred_kwh = y_pred_kwh.flatten()
y_pred_bill = y_pred_bill.flatten()

# Calculate evaluation metrics
print("MODEL EVALUATION RESULTS")
print("=" * 50)

# kWh prediction metrics
kwh_mae = mean_absolute_error(y_kwh_test, y_pred_kwh)
kwh_mse = mean_squared_error(y_kwh_test, y_pred_kwh)
kwh_rmse = np.sqrt(kwh_mse)
kwh_r2 = r2_score(y_kwh_test, y_pred_kwh)

print(f"kWh Prediction Metrics:")
print(f"MAE: {kwh_mae:.2f} kWh")
print(f"RMSE: {kwh_rmse:.2f} kWh")
print(f"R²: {kwh_r2:.4f}")

# Tariff prediction metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

tariff_accuracy = accuracy_score(y_tariff_test, y_pred_tariff)
tariff_precision = precision_score(y_tariff_test, y_pred_tariff, average='weighted')
tariff_recall = recall_score(y_tariff_test, y_pred_tariff, average='weighted')
tariff_f1 = f1_score(y_tariff_test, y_pred_tariff, average='weighted')

print(f"\nTariff Bracket Prediction Metrics:")
print(f"Accuracy: {tariff_accuracy:.4f}")
print(f"Precision: {tariff_precision:.4f}")
print(f"Recall: {tariff_recall:.4f}")
print(f"F1-Score: {tariff_f1:.4f}")


# Bill prediction metrics
bill_mae = mean_absolute_error(y_bill_test, y_pred_bill)
bill_mse = mean_squared_error(y_bill_test, y_pred_bill)
bill_rmse = np.sqrt(bill_mse)
bill_r2 = r2_score(y_bill_test, y_pred_bill)

print(f"\nBill Prediction Metrics:")
print(f"MAE: {bill_mae:.2f} RWF")
print(f"RMSE: {bill_rmse:.2f} RWF")
print(f"R²: {bill_r2:.4f}")

# Plot predictions vs actual values
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# kWh predictions
axes[0].scatter(y_kwh_test, y_pred_kwh, alpha=0.5)
axes[0].plot([y_kwh_test.min(), y_kwh_test.max()], [y_kwh_test.min(), y_kwh_test.max()], 'r--', lw=2)
axes[0].set_xlabel('Actual kWh')
axes[0].set_ylabel('Predicted kWh')
axes[0].set_title('kWh Prediction Accuracy')

# Bill predictions
axes[1].scatter(y_bill_test, y_pred_bill, alpha=0.5)
axes[1].plot([y_bill_test.min(), y_bill_test.max()], [y_bill_test.min(), y_bill_test.max()], 'r--', lw=2)
axes[1].set_xlabel('Actual Bill (RWF)')
axes[1].set_ylabel('Predicted Bill (RWF)')
axes[1].set_title('Bill Prediction Accuracy')

# Tariff confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_tariff_test, y_pred_tariff)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[2],
            xticklabels=label_encoders['Tariff_Bracket'].classes_,
            yticklabels=label_encoders['Tariff_Bracket'].classes_)
axes[2].set_xlabel('Predicted Tariff')
axes[2].set_ylabel('Actual Tariff')
axes[2].set_title('Tariff Bracket Confusion Matrix')

plt.tight_layout()
plt.show()
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MODEL EVALUATION RESULTS
# ==================================================
# kWh Prediction Metrics:
# MAE: 8.03 kWh
# RMSE: 14.34 kWh
# R²: 0.9968
#
# Tariff Bracket Prediction Metrics:
# Accuracy: 0.9359
# Precision: 0.9360
# Recall: 0.9359
# F1-Score: 0.9329
#
# Bill Prediction Metrics:
# MAE: 1978.65 RWF
# RMSE: 3837.04 RWF
# R²: 0.9983
